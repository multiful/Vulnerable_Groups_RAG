# %% [markdown]
#   🖊️  사용자가 직접 데이터 채워야 함
#
#   ┌─────┬────────────────────────────────────────────────────────┬──────────────────────────────────────────┬─────────────────┐
#   │  #  │                          항목                          │                   이유                   │      규모       │
#   ├─────┼────────────────────────────────────────────────────────┼──────────────────────────────────────────┼─────────────────┤
#   │     │ DAG 0% 도메인                                          │ 전부 민간/비기술 자격증이라 NCS 위계     │ 6개 도메인,     │
#   │ 4   │ (금융/회계·경영/사무·사회복지·의료/보건·교육·관광 등)  │ 자동 생성 불가. 실제 선행/후행 관계는    │ 합계 약 184개   │
#   │     │                                                        │ 도메인 지식 필요                         │ 자격증          │
#   ├─────┼────────────────────────────────────────────────────────┼──────────────────────────────────────────┼─────────────────┤
#   │     │                                                        │ Q-Net 원본 미수록 자격증 (희귀           │                 │
#   │ 5   │ 합격률 없는 396개                                      │ 기술사·면허 등). 공식 사이트에서 수동    │ 396개           │
#   │     │                                                        │ 수집 필요                                │                 │
#   ├─────┼────────────────────────────────────────────────────────┼──────────────────────────────────────────┼─────────────────┤
#   │ 6   │ 시험 과목 없는 621개                                   │ 동일. 원본 출처 없으면 채울 방법 없음    │ 621개           │
#   ├─────┼────────────────────────────────────────────────────────┼──────────────────────────────────────────┼─────────────────┤
#   │ 7   │ related_jobs 없는 75개 (민간자격)                      │ job taxonomy와 매핑할 기준 데이터 없음.  │ 75개            │
#   │     │                                                        │ 직무 분류 수동 지정 필요                 │                 │
#   ├─────┼────────────────────────────────────────────────────────┼──────────────────────────────────────────┼─────────────────┤
#   │ 8   │ 도메인 자격증 부족 (데이터/AI 12개, IT인프라 11개,     │ 새 자격증 원본 데이터 확보 필요          │ -               │
#   │     │ 영업/CS 1개)                                           │                                          │                 │
#   ├─────┼────────────────────────────────────────────────────────┼──────────────────────────────────────────┼─────────────────┤
#   │ 9   │ exam_fee 컬럼                                          │ text_for_dense에 응시료 정보 0건. 전혀   │ 전체            │
#   │     │                                                        │ 수집 안 됨                               │                 │
#   └─────┴────────────────────────────────────────────────────────┴──────────────────────────────────────────┴─────────────────┘

# %% [markdown]
# # API !
#
# 현재 API 정리를 했어. 이제 더 고도화 해서 기능들을 추가해야해.
#
# [참고 내용 - 서울시공공데이터 공모전 언급 x 프로젝트 이해만 할 것. 현 상태임]
#
# DBMs_DIDIM_상세기획서.pptx
# DBMs_DIDIM_설명.pdf
#
# 이 내용에서 더 고도화를 해야해. 특히 아래 API를 참고해서 전체적으로 보완 + 추가 기능 개발을 목표로 할거야.
#
#
# ---
#
# [국가기술자격 API 참고 문헌]
#
# - 국가기술자격 취득 관련 현황
# 연도별 취득 트렌드를 분석하여 현재 시장에서 가장 '수요가 많은' 인기 자격증을 우선 추천할 수 있습니다.
# docs/references/국가기술자격_취득 관련 현황.docx
#
# - 국가자격 관심자격 정보
# 사용자들의 찜(관심) 목록 데이터를 기반으로 실시간 선호도가 높은 자격증 큐레이션을 제공합니다.
# docs/references/국가자격 관심자격 정보.docx
#
# - 국가기술자격 학과별 직무정보
# 사용자의 '전공'과 '자격증' 사이의 연관성을 팩트 기반으로 연결하여 추천 근거를 생성합니다.
# docs/references/국가기술자격_학과별 직무정보.docx
#
# - 연도별 회별 국가기술자격 합격률
# 종목별 난이도를 수치화하여 사용자의 역량 수준(1~5단계)에 맞는 적정 난이도의 자격증을 필터링합니다.
# docs/references/연도별 회별 국가기술자격 합격률.docx
#
# - 국가자격 취득자 관련 통계 정보
# 성별·연령별 합격 데이터를 통해 사용자 페르소나와 가장 유사한 집단이 많이 따는 자격증을 추천합니다.
# docs/references/국가기술자격_취득자 관련 통계 정보.docx
#
# - 한국산업인력공단_국가자격 시험일정 조회 서비스
# 사용자가 추천받은 자격증을 즉시 접수할 수 있도록 실시간 시험 접수 기간과 디데이(D-Day) 정보를 출력합니다.
# docs/references/[한국산업인력공단]국가자격 시험일정.docx
#
# - 국가자격 종목 목록 정보
# 자격증의 정의, 수행 직무, 관련 부처 등 공식적인 개요 정보를 RAG의 기초 지식으로 활용합니다.
# docs/references/국가 자격 종목 목록 정보.pdf
#
# - 한국산업인력공단_국가자격 종목별 자격정보
# 자격증별 개요, 수행 직무, 취득 방법 등 공식 가이드를 제공하여 사용자가 해당 자격의 실제 역할과 가치를 명확히 이해하고 도전하게 돕습니다.
# docs/references/국가자격 종목별 자격정보.pdf
#
# - 한국산업인력공단_국가기술자격 종목별 시험정보
# 종목별 상세 시험 과목, 검정 방법, 합격 기준을 출력하여 사용자가 구체적인 학습 범위와 수험 전략을 세울 수 있도록 지원합니다.
# docs/references/국가기술자격 종목별 시험 일정 정보.pdf
#
#
# - 한국산업인력공단_NCS 능력단위별 자격 종목 조회 서비스
# 자격증 취득에 필요한 '최소 훈련 시간'을 제시하여 사용자가 학습 분량을 미리 가늠하고 계획할 수 있게 돕습니다.
# docs/references/[한국산업인력공단]NCS 능력단위별 자격 종목 조회.docx
#
# - 한국산업인력공단_과정평가형, 일학습병행 통계연보
# 시험 부담이 큰 고위험군(4~5단계)에게 합격률이 높은 '교육 이수형' 자격 취득 경로를 대안으로 제시합니다.
# docs/references/OPEN-API_과정평가형자격_일학습병행관련_통계_연보_데이터_기술문서.docx
#
# - 한국산업인력공단_과정평가형일학습병행 과정 지정평가 관련 정보 조회 서비스
# 사용자 위치 기반으로 '지금 바로 참여 가능한' 인근 교육 기관과 훈련 일정 매칭 서비스를 제공합니다.
# docs/references/OPEN-API_과정평가형일학습병행 과정지정평가관련정보.docx
#
# - 한국산업인력공단_과정평가형자격 정보 조회
# 과정평가형 자격의 상세 커리큘럼(능력단위)과 외부 평가 일정을 안내하여 체계적인 학습 로드맵을 구성합니다.
#
# 과정평가형 종목 목록 조회	제공형태, 페이지번호, 페이지당 데이터 수를 조회 조건으로 조회되는 종목 목록의 중직무분야, 종목명, 종목코드, 종목영문명, 관리부처, 시행기관명 등의 정보를 제공하는 “과정평가형 종목 목록 조회” API 서비스
# 과정평가형 종목별 자격정보 조회	상세기능 번호1에서 조회한 종목목록의 종목코드 및 제공형태를 조회조건으로 종목코드별 종목명, 종목코드, 편성기준버전, 개요, 목표, 총 시간, 기초능력시간, 필수능력시간, 선택능력시간, 관련부처, 시행기관명, 실시기관명, 실시기관홈페이지, 진로 및 희망, 능력단위목록(능력단위명, 능력단위유형, 최소교육시간) 정보를 조회하는 “과정평가형자격 정보 조회”
# 과정평가형 외부평가 일정정보 조회	조회하고자 하는 시행년도, 페이지번호, 페이지당 데이터 수 및 제공형태별 시행계획명, 접수시작일, 접수종료일, 시험시작일, 시험종료일, 합격자발표일 정보를 조회하는 “과정평가형 외부평가 일정정보 조회” API 서비스로 CQ-Net(c.q-net.or.kr) 홈페이지에서 공고되는 시행계획만 서비스로 제공
#
# - 한국산업인력공단_국가전문자격 시험 시행일정 정보
# 전문자격의 시험 일정 정보 참고
# docs/references/국가전문자격 시험 시행일정 조회.pdf
#
# docs/references/과정평가형자격_기술문서_20180817.docx
#
# ----
#
# [대졸자 분석 후 통계 + 자격증 통계 + 설문 분석] + 취업자 + 자격증 + 전공 + 직무/일자리 경험
#
# 실제 대졸 취업자들의 전공-자격증-직업 간의 실례(Instance)를 분석하여 초정밀 직무 매칭 알고리즘을 구현합니다.
#
# data/raw/csv/GP19__2020.XLSX
# data/raw/pdf/2020_대졸자직업이동경로조사(2019GOMS)_설문지.pdf
# data/raw/csv/2019goms_code book.xlsx
#
# ---
#
# [커리어넷] - backend/.env 의 CAREER_NET_API_KEY
#
#
# - 학과정보
# XML 형태 URL : https://www.career.go.kr/cnet/openapi/getOpenApi?apiKey=인증키&contentType=xml
# JSON 형태 URL : https://www.career.go.kr/cnet/openapi/getOpenApi?apiKey=인증키&contentType=json
#
# - 직업정보
# XML 형태 URL : //www.career.go.kr/cnet/openapi/getOpenApi.xml?apiKey=인증키
# JSON 형태 URL : https://www.career.go.kr/cnet/openapi/getOpenApi?apiKey=인증키&contentType=json
#
#
# ----
#
# [서울데이터광장]
# - 고립은둔 청년 실태조사 결과 현황 (https://www.data.go.kr/data/15146169/fileData.do?recommendDataYn=Y)
#     - data/raw/csv/★TABLE_서울시 고립은둔청년 실태조사(청년조사)_전체_v1_230127 (2).xlsx
#
#
# - data/raw/csv/고용24 직업정보상세 요약.csv
#     - 직업만족율, 취업방법, 직업안내동영상, 직업근무내용, 임금, 직업예상 등을 잘 출력할 수 있을 것.
#
# - 서울시 공공서비스(예약)종합 정보 (https://data.seoul.go.kr/dataList/OA-20497/S/1/datasetView.do)
#     - backend/.env 의 SEOUL_API_KEY
#
#
# - 서울시 건강증진센터(표준 데이터) (https://data.seoul.go.kr/dataList/OA-20438/S/1/datasetView.do)
#     - backend/.env 의 SEOUL_API_KEY2
#     - 정신건강상담센터 위치 API: 고위험군 청년에게 실질적인 '돌봄'의 느낌을 주기 위해 필요합니다.
#
# - 서울시 일자리카페 정보(https://data.seoul.go.kr/dataList/OA-15356/S/1/datasetView.do)
#     - backend/.env 의 SEOUL_API_KEY3
#
#
#
# ---
#
# [고용노동부]
#
# - 한국고용정보원_워크넷 채용정보 채용목록 및 상세정보
#
#     - 채용정보 API - 인증키는 backend/.env의 GET_JOB_API_KEY
#     - http://openapi.work.go.kr/opi/opi/opia/wantedApi.do
#     - https://www.data.go.kr/data/3038225/openapi.do
#
# 기본검색(필수 입력 예)
#
# http://openapi.work.go.kr/opi/opi/opia/wantedApi.do?authKey=[인증키]&callTp=L&returnType=XML&startPage=1&display=10
#
# 다중검색(다중검색 입력 예)
#
# http://openapi.work.go.kr/opi/opi/opia/wantedApi.do?authKey=[인증키]&callTp=L&returnType=XML&startPage=1&display=10&occupation=[직종코드1|직종코드2]
#
# * 요청 parameter 입력 시, 대괄호 [ ]는 제외합니다.
#
# 1.2 요청 parameter
# 항목	타입	필수여부	설명
# authKey	String	Y	인증키
# callTp	String	Y	호출할 페이지 타입을 반드시 설정합니다.(L: 목록, D:상세)
# returnType	String	Y	xml 를 반드시 지정합니다.
# startPage	Number	Y	기본값 1, 최대 1000 검색 시작위치를 지정할 수 있습니다.
# 최대 1000 까지 가능합니다.
# display	Number	Y	출력건수, 기본값 10, 최대 100 까지 가능합니다.
# region	String	 	(다중검색 가능)
# 근무지역코드를 입력합니다.
# 근무지역코드 보기
# occupation	String	 	(다중검색 가능)
# 직종코드를 입력합니다.
# 직종코드 보기
#
# * 다수의 직종코드를 한번에 입력할 경우 API 이용에 제한이 있을 수 있습니다.(예: 100개 이상)
# salTp	String
# 임금형태
#
# D 일급
# H 시급
# M 월급
# Y 연봉
# * 검색조건 미입력시 관계없음으로 조회됩니다.
#
# minPay	Number	임금형태 입력시 필수 입력
# 최소급여
#
# ~ 만원(원)이상 : 연봉,월급(일급,시급) 검색값 입력 시
# 천단위구분을 위한 콤마(,)는 입력하지 않습니다.
# maxPay	Number	임금형태 입력시 필수 입력
# 최대급여
#
# ~ 만원(원)이상 : 연봉,월급(일급,시급) 검색값 입력 시
# 천단위구분을 위한 콤마(,)는 입력하지 않습니다.
# education	String
# 학력 코드를 입력합니다.
#
# 00 학력무관
# 01 초졸이하
# 02 중졸
# 03 고졸
# 04 대졸(2~3년)
# 05 대졸(4년)
# 06 석사
# 07 박사
# *학력무관(00) 입력시 다수 항목 입력 불가.
# career	String
# 경력 코드를 입력합니다.
#
# N 신입
# E 경력
# Z 관계없음
# * 경력의 경우 반드시 경력최소개월,경력최대개월을 입력
# minCareerM	Number	경력코드 입력시 필수입력	경력 최소개월 수
# maxCareerM	Number	경력코드 입력시 필수입력	경력 최대개월 수
# pref	String	 	(다중검색 가능)
# 우대조건
#
# Y 장애인 병행채용
# D 장애인만 채용
# subway	String	 	(다중검색 가능)
# 역세권 코드를 입력합니다.
# 역세권코드 보기
# * 지역-호선-역 코드 의 형식으로 입력하십시오.
# empTp	String	 	(다중검색 가능)
# 고용형태
#
# 4 파견근로
# 10 기간의 정함이 없는 근로계약
# 11 기간의 정함이 없는 근로계약(시간(선택)제)
# 20 기간의 정함이 있는 근로계약
# 21 기간의 정함이 있는 근로계약(시간(선택)제)
# Y 대체인력채용
# termContractMmcnt	String	 	(다중검색 가능)
# 근무기간
#
#  1 1~3개월
#  3 3~6개월
#  6 6~12개월
# 12 12개월 이상
# * 고용형태가 시간선택제(11,21)인 경우에만 적용됨.
# holidayTp	String	 	(다중검색 가능)
# 근무형태
#
# 1 주 5일 근무
# 2 주 6일 근무
# 3 토요 격주 휴무
# 9 기타
# coTp	String	기업형태 택일	(다중검색 가능)
# 기업형태
#
# 01 대기업
# 03 벤처기업
# 04 공공기관
# 05 외국계기업
# 09 청년친화강소기업
# busino	String		사업자등록번호
# dtlSmlgntYn	String
# 강소기업 여부 (Y)
#
# workStudyJoinYn	String
# 일학습병행기업 여부(Y)
#
# smlgntCoClcd	String	기업형태 택일
# 기업형태
#
# 강소기업 분류코드를 입력합니다.
# 강소기업분류코드 보기
# workerCnt	String
# 사원수
#
# W5 5인 미만
# W9 5인 ~ 10인
# W10 10인 ~ 30인
# W30 30인 ~ 50인
# W50 50인 ~ 100인
# W100 100인 이상
# welfare	String	 	(다중검색 가능)
# 근무편의
#
# 01 기숙사
# 02 통근버스
# 04 중식제공(또는 중식비 지원)
# 11 차량유지비
# 12 교육비 지원
# 13 자녀학자금 지원
# 06 주택자금 지원
# 09 기타
# certLic	String	 	(다중검색 가능)
# 자격면허 코드를 입력합니다.
# 자격면허코드 보기
# regDate	String
# D-0 오늘
# D-3 3일
# M-1 한달
# W-1 1주 이내
# W-2 2주 이내
# keyword	String	 	(다중검색 가능)
# 키워드검색 (예)전략영업, 개발자, ERP), UTF-8 인코딩입니다.
# untilEmpWantedYn	String	 	채용시까지 구인여부 : Y/N
# minWantedAuthDt	String	 	최소 구인인증일자
# maxWantedAuthDt	String	 	최대 구인인증일자
# empTpGb	String
# 채용구분색 가능)
# 외국어코드를 입력합니다.
# 언어코드 보기
# comPreferential	String	 	(다중검색 가능)
# 기타 우대조건 (컴퓨터 활용)
#
# 1 문서작성
# 2 스프레드시트
# 4 프리젠테이션
# 6 회계프로그램
# 9 기타
# pfPreferential	String	 	(다중검색 가능)
# 기타 우대조건 (일반)
#
# 05 차량소지자
# 07 고용촉진장려금대상자
# 08 보훈취업지원대상자
# 09 장기복무 제대군인
# 10 북한이탈주민
# 14 운전가능자
# S 장애인
# B (준)고령자(50세이상)
# workHrCd	String	 	(다중검색 가능)
# 근무시간
#
# 1 오전(06:00~12:00)
# 2 오후(12:00~18:00)
# 3 저녁(18:00~24:00)
# 4 새벽(00:00~06:00)
# 5 오전~오후
# 6 오후~저녁
# 7 저녁~새벽
# 8 새벽~오전
# 9 종일 근무(09:00~18:00)
# 99 시간협의/무관
#
# - 한국고용정보원_직업훈련_국민내일배움카드 훈련과정
#     - 국민내일배움카드 훈련과정 API
#         - 인증키는 backend/.env의 GET_TRAINING_API_KEY
#         - https://www.data.go.kr/data/15109032/openapi.do?recommendDataYn=Y
#
# 1. 요청 URL
# https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do
# 복사
# 2. 사용예제
# 예제1) 기본 조건만을 이용하여 검색하는 경우
#
# https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do?authKey=[인증키]&returnType=XML&outType=1&pageNum=1&pageSize=20&srchTraStDt=20141001&srchTraEndDt=20141231&sort=ASC&sortCol=2
# 복사
# 예제2) 선택조건을 추가하는 경우
#
# https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do?authKey=[인증키]&returnType=XML&outType=1&pageNum=1&pageSize=20&srchTraStDt=20141001&srchTraEndDt=20141231&srchTraArea1=[훈련지역 대분류]&sort=ASC&sortCol=2
# 복사
#
# * 요청 Parameters 입력시 대괄호 []는 제외합니다.
#
# 3. 요청 Parameters
# 항목,타입,필수여부,설명을(를) 제공하는 표
# 항목	타입	필수여부	설명
# authKey	string	필수	인증키(ex : authKey=[인증키]
# returnType	string	필수	리턴타입:XML, JSON 중 하나로 지정합니다.(ex : returnType=XML)
# outType	string	필수	구분자 : 출력형태('1':리스트 '2':상세)
# pageNum	string	필수	시작페이지. 기본값 1, 최대 1000 검색 시작위치를 지정할 수 있습니다. 최대 1000 까지 가능.
# pageSize	string	필수	페이지당 출력건수, 기본값 10, 최대 100까지 가능.
# wkendSe	string	선택	주말/주중 구분	주말 : 1
# 주말 주중 혼합 : 2
# 주중 : 3
# 해당없음 : 9
# * 전체일 경우에는 옵션 파라미터의 미등록처리
# srchTraArea1	string	선택	훈련지역 대분류	'11' : 서울, '26' : 부산, '27' : 대구, '28' : 인천 '29' : 광주, '30' : 대전, '31' : 울산, '36' : 세종, '41' : 경기, '43' : 충북, '44' : 충남, '45' : 전북, '46' : 전남, '47' : 경북, '48' : 경남, '50' : 제주, '51' : 강원
# * 전체일 경우에는 옵션 파라미터의 미등록처리
# srchTraArea2	string	선택	훈련지역 중분류
# 훈련지역 대분류에 따라 내용이 달라짐	* 해당 코드관련 API 제공
# * 훈련지역 대분류 제외시 이항목도 옵션 파라미터에 미등록처리
# srchNcs1	string	선택	NCS 직종 1차분류 코드	'01' : 사업관리
# '02' : 경영/회계/사무
# '03' : 금융/보험
# '04' : 교육/자연/사회과학
# '05' : 법률/경찰/소방/교도/국방
# '06' : 보건/의료
# '07' : 사회복지/종교
# '08' : 문화/예술/디자인/방송
# '09' : 운전/운송
# '10' : 영업판매
# '11' : 경비/청소
# '12' : 이용/숙박/여행/오락/스포츠	'13' : 음식서비스
# '14' : 건설
# '15' : 기계
# '16' : 재료
# '17' : 화학/바이오
# '18' : 섬유/의복
# '19' : 전기/전자
# '20' : 정보통신
# '21' : 식품가공
# '22' : 인쇄/목재/가구/공예
# '23' : 환경/에너지/안전
# '24' : 농림어업
# * 전체일 경우에는 옵션 파라미터의 미등록처리
# srchNcs2	string	선택	NCS 직종 2차분류 코드
# 상위분류에 따라 내용이 달라짐	* 해당 코드관련 API 제공
# * 전체일 경우에는 옵션 파라미터의 미등록처리
# srchNcs3	string	선택	NCS 직종 3차분류 코드
# 상위분류에 따라 내용이 달라짐	* 해당 코드관련 API 제공
# * 전체일 경우에는 옵션 파라미터의 미등록처리
# srchNcs4	string	선택	NCS 직종 4차분류 코드
# 상위분류에 따라 내용이 달라짐	* 해당 코드관련 API 제공
# * 전체일 경우에는 옵션 파라미터의 미등록처리
# crseTracseSe	string	선택	훈련유형	'C0061' : 국민내일배움카드(일반)
# 'C0061S' : 국민내일배움카드(주 훈련대상 : 구직자)
# 'C0061I' : 국민내일배움카드(주 훈련대상 : 재직자)
# 'C0054' : 국가기간전략산업직종
# 'C0055C' : 과정평가형훈련
# 'C0054G' : 기업맞춤형훈련
# 'C0054Y' : 스마트혼합훈련
# 'C0054S' : 일반고특화훈련
# 'C0104' : K-디지털 트레이닝
# 'C0105' : K-디지털 기초역량훈련
# 'C0102' : 산업구조변화대응
# 'C0055' : 실업자 원격훈련
# 'C0031' : 근로자 원격훈련
# 'C0031C' : 돌봄서비스훈련
# 'C0031F' : 근로자 외국어훈련
# * 전체일 경우에는 옵션 파라미터의 미등록처리
# srchTraGbn	string	선택	훈련구분코드	'M1001' : 일반과정
# 'M1005' : 인터넷과정
# 'M1010' : 혼합과정(BL)
# 'M1014' : 스마트혼합훈련
# * 전체일 경우에는 옵션 파라미터의 미등록처리
# srchTraType	string	선택	훈련종류(훈련구분에 따라 세부내용이 변경됨)	'* 해당 코드관련 API 제공
# * 훈련지역 대분류 제외시 이항목도 옵션 파라미터에 미등록처리
# * 인터넷과정과 혼합과정의 경우 세부항목이 없음
# srchTraStDt	string	필수	훈련시작일 From
# srchTraEndDt	string	필수	훈련시작일 To
# srchTraProcessNm	string	선택	훈련과정명
# srchTraOrganNm	string	선택	훈련기관명
# sort	string	필수	정렬방법	"ASC",
# "DESC"
# sortCol	string	필수	정렬컬럼	훈련기관명 : 1
# 훈련시작일 : 2
# 훈련기관 직종별 취업률 : 3
# 만족도점수 : 5

# %% [markdown]
# # PROJECT : DIDIM (디딤)
#
# ## ROLE
#
# 너는 시니어 AI 플랫폼 아키텍트 + 풀스택 엔지니어다.
#
# 현재 운영 중인 DIDIM 프로젝트를 고도화한다.
#
# 기존 프로젝트는:
# - React + Vite frontend
# - FastAPI backend
# - Supabase + pgvector
# - RAG 기반 추천 시스템
# - 위험 단계 기반 자격증 추천 시스템
#
# 으로 구성되어 있다.
#
# 기존 구조를 유지하면서:
# "실시간 실행형 진로 회복 플랫폼"
# 수준으로 고도화한다.
#
# 절대 기존 아키텍처를 무시하고 새로 만들지 말 것.
#
# 기존 구조를 분석 후 확장하라.
#
# ---
#
# # CORE PRODUCT GOAL
#
# DIDIM은 단순 자격증 추천 서비스가 아니다.
#
# 목표는:
#
# 1. 사용자 상태 분석
# 2. 전공/직무 기반 자격증 추천
# 3. 실제 취업 사례 기반 설명
# 4. 실행 가능한 다음 행동 제안
# 5. 공공데이터 기반 신뢰성 제공
#
# 이다.
#
# ---
#
# # VERY IMPORTANT
#
# ## DO NOT
#
# - 단순 GPT 챗봇처럼 구현 금지
# - 랜덤 추천 금지
# - 환각 데이터 생성 금지
# - 코드체계 무시 금지
# - 직접 문자열 매칭 금지
#
# ## MUST
#
# - Canonical Mapping Layer 구축
# - 모든 추천은 근거 기반
# - 추천 이유 설명 가능해야 함
# - API 실패 대비 fallback 필요
# - 공공데이터 원문 기반 유지
#
# ---
#
# # SYSTEM ARCHITECTURE
#
# ## Existing
#
# Frontend:
# - React
# - Vite
# - Tailwind
#
# Backend:
# - FastAPI
# - LangChain
# - pgvector
# - Supabase
#
# AI:
# - RAG Retrieval
# - taxonomy normalization
#
# ---
#
# # NEW TARGET ARCHITECTURE
#
# [ USER INPUT ]
# ↓
# Psychological Stage + Major + Interest + Region
# ↓
# [ Canonical Mapping Layer ]
# major_code
# ↔ job_code
# ↔ NCS_code
# ↔ cert_code
# ↔ worknet_code
# ↓
# [ Recommendation Engine ]
# - GOMS statistics
# - pass rate
# - popularity trend
# - interest cert trend
# - stage filtering
# ↓
# [ DAG Roadmap Engine ]
# reachable certification path only
# ↓
# [ Execution Layer ]
# - nearby training center
# - exam schedule
# - job cafe
# - public reservation
# - live hiring jobs
# ↓
# [ RAG Evidence Layer ]
# official documents only
# ↓
# [ Explainable UI ]
# "why recommended"
#
# ---
#
# # TOP PRIORITY
#
# ## 1. CANONICAL DATA LAYER
#
# This is the most important task.
#
# Create normalized mapping tables for:
#
# - GOMS major
# - CareerNet major
# - WorkNet occupation
# - NCS codes
# - certification codes
# - HRD training categories
#
# Design:
#
# canonical_major
# canonical_job
# canonical_cert
# canonical_ncs
#
# Use alias normalization:
# - typo handling
# - synonym handling
# - Korean spacing normalization
#
# taxonomy.txt must remain central.
#
# NEVER directly connect APIs without normalization.
#
# ---
#
# # GOMS ENGINE
#
# Use:
#
# GP19__2020.XLSX
# 2019goms_code book.xlsx
#
# Build:
#
# major
# → certification
# → first job
# → occupation transition
#
# analysis pipeline.
#
# Generate:
#
# - major-cert relationship score
# - cert-job relationship score
# - major-job transition score
#
# IMPORTANT:
#
# This is correlation-based recommendation.
# Never claim causation.
#
# Use wording like:
# - "연관 경로"
# - "실제 사례 기반"
# - "유사 전공 사례"
#
# Never:
# - "취업 성공 보장"
#
# ---
#
# # RECOMMENDATION ENGINE
#
# Recommendation score should combine:
#
# 1. stage score
# 2. difficulty score
# 3. pass rate
# 4. popularity trend
# 5. GOMS relevance
# 6. hiring demand
# 7. training accessibility
# 8. nearby availability
#
# Formula should be configurable.
#
# ---
#
# # STAGE-BASED FILTERING
#
# Stage 1~2:
# - self-study track
# - 기사/산업기사 allowed
#
# Stage 3:
# - balanced track
#
# Stage 4~5:
# - process-based qualification
# - short-term achievement
# - home-study friendly
# - low barrier certification
#
# IMPORTANT:
# Do not use medical wording.
#
# Use:
# - support stage
# - recovery stage
# - activity readiness
#
# instead of:
# - high risk
# - mental illness
#
# ---
#
# # DAG ROADMAP ENGINE
#
# Existing DAG structure must remain.
#
# Enhance with:
#
# - estimated study duration
# - prerequisite relationship
# - difficulty progression
# - branch visualization
#
# Users should only see:
# "reachable next path"
#
# Never show impossible jumps.
#
# ---
#
# # RAG SYSTEM
#
# Current RAG exists.
#
# Upgrade with:
#
# ## Sources
#
# - 국가자격 종목 목록 정보
# - 종목별 자격정보
# - 시험정보
# - 과정평가형 정보
# - NCS 정보
#
# ## Rules
#
# - Retrieval-only generation
# - no hallucination
# - snippet citation required
# - if no evidence:
#   "설명 근거 없음"
#
# ## Chunk metadata
#
# Store:
# - source
# - cert_code
# - cert_name
# - job_domain
# - updated_at
#
# ---
#
# # REALTIME EXECUTION LAYER
#
# Implement:
#
# ## 1. Exam Schedule
#
# Display:
# - registration period
# - exam period
# - D-day
#
# ## 2. WorkNet Hiring
#
# Live hiring count:
# "현재 지원 가능한 채용공고 n건"
#
# Use:
# - occupation code
# - certification code
# - region
#
# ## 3. HRD Training
#
# Display:
# - nearby academy
# - 국비지원 여부
# - satisfaction
# - employment rate
#
# ## 4. Seoul Job Cafe
#
# Show nearby:
# - study spaces
# - reservation support
#
# ## 5. Public Reservation
#
# "오늘 공부하러 가기"
#
# CTA-based UI.
#
# ## 6. Wellness Support
#
# For recovery-stage users:
# show nearby counseling/wellness center softly.
#
# Never force.
#
# ---
#
# # UI/UX REQUIREMENTS
#
# Tone:
# - warm
# - non-medical
# - hopeful
# - realistic
#
# Avoid:
# - authoritarian wording
# - diagnosis wording
#
# Must emphasize:
# - small achievement
# - next step
# - realistic path
#
# ---
#
# # MAIN SCREEN
#
# Show:
#
# 1. current stage
# 2. recommended roadmap
# 3. WHY explanation
# 4. real hiring demand
# 5. nearby training
# 6. exam D-day
# 7. today's one action
#
# ---
#
# # TODAY ONE ACTION SYSTEM
#
# Generate ONE small action:
#
# Examples:
# - reserve study cafe
# - watch intro lecture
# - apply for exam
# - visit training center
#
# This is critical.
#
# ---
#
# # JOB-VIEW DASHBOARD
#
# Build visualization for:
#
# - salary
# - satisfaction
# - future outlook
# - real tasks
# - related videos
#
# using:
# 고용24 직업정보상세 요약.csv
#
# ---
#
# # PERFORMANCE
#
# Because public APIs are slow:
#
# Implement:
# - Redis caching
# - batch sync
# - scheduled ETL
#
# Avoid excessive realtime API calls.
#
# ---
#
# # DATABASE
#
# Recommended:
#
# PostgreSQL
# + pgvector
# + Redis
#
# Optional:
# Neo4j for graph visualization.
#
# ---
#
# # GRAPH VISUALIZATION
#
# Optional advanced feature:
#
# major
# → cert
# → job
# → hiring
#
# graph visualization.
#
# Neo4j allowed.
#
# ---
#
# # API RULES
#
# All external APIs must:
#
# - timeout safe
# - retry safe
# - schema validated
# - normalized before use
#
# Never expose raw API response directly.
#
#
# ---
# # 상시 추가 내용 ( 5.14.06 )
# - 카카오 지도 API를 사용해서 건강증진센터, 일자리카페, 공공서비스(예약)종합 정보를 제공하고 지도 시각화 제공
#
#
# ---
#
# # OUTPUT REQUIREMENTS
#
# Generate:
#
# 1. backend architecture
# 2. frontend architecture
# 3. folder structure
# 4. DB schema
# 5. ETL pipeline
# 6. API integration layer
# 7. recommendation engine
# 8. DAG engine
# 9. RAG pipeline
# 10. deployment architecture
# 11. env structure
# 12. caching strategy
# 13. implementation roadmap
#
# ---
#
# # IMPLEMENTATION PRIORITY
#
# PHASE 1
# - canonical mapping
# - recommendation engine
# - exam API
# - training API
#
# PHASE 2
# - GOMS integration
# - WorkNet integration
# - hiring dashboard
#
# PHASE 3
# - RAG enhancement
# - graph visualization
# - advanced reranking
#
# ---
#
# # FINAL IMPORTANT RULE
#
# DIDIM is NOT:
# "a chatbot"
#
# DIDIM IS:
# "a data-driven recovery and career navigation platform"
#
# All implementations must preserve this philosophy.
